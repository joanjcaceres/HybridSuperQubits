# %%
from qutip import *
import ferbo
import importlib
importlib.reload(ferbo)
from ferbo import Ferbo
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget

# %%
test = ferbo.Ferbo(Ec = 50, El=0.01, Delta=40)

# %%
kk = test.get_phase_matrix_element_vs_El(0, 1, El_array=np.linspace(0.05, 0.2, 100))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x = test.get_eigenenergies_vs_external_phase(eigvals=6, phi_ext_array=np.linspace(-2*np.pi, 2*np.pi, 100))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y = test.get_eigenenergies_vs_r(eigvals=6, r_array=np.linspace(0, 1, 100))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
z = test.get_eigenenergies_vs_Ec(eigvals=6, Ec_array=np.linspace(10, 80, 50))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
a = test.get_eigenenergies_vs_El(eigvals=6, El_array=np.linspace(0.005, 0.01, 30))
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
b = test.get_eigenenergies_vs_Delta(eigvals=6, Delta_array=np.linspace(10, 40, 50))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
