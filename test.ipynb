# %%
from qutip import *
import importlib
import ferbo
importlib.reload(ferbo)
from ferbo import Ferbo
import matplotlib.pyplot as plt
import numpy as np

# %%
test = ferbo.Ferbo(Ec = 50, El=0.05, Delta=40)

# %%
x = test.get_eigenenergies_vs_external_phase(eigvals=6,phi_ext_array=np.linspace(0,2*np.pi,100))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
plt.plot(x)
