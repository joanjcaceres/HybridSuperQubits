# %%
import importlib
import numpy as np
import ferbo as fb
importlib.reload(fb)
# %matplotlib widget

# %%
fixed_params = {
    'Ec': 40,
    'El': 0.05,
    'Delta': 20,
    'r': 0.05,
    'dimension': 100
}

phi_ext_array = np.linspace(0, 2*np.pi, 100)

# Llamar a la función
eigenenergies = fb.eigenenergies_vs_parameter('phi_ext', phi_ext_array, fixed_params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fixed_params = {
    'Ec': 50,
    'El': 0.05,
    'Delta': 20,
    'r': 0.05,
    'dimension': 100
}

phi_ext_array = np.linspace(0, 2*np.pi, 100)

# Llamar a la función
eigenenergies = fb.matrix_elements_vs_parameter(parameter_name='phi_ext', parameter_values=phi_ext_array, operator_name='phase', fixed_params=fixed_params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
